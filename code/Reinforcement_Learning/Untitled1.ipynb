# %%
import pandas as pd
import matplotlib.pyplot as plt
import time as tm
import os

import numpy as np
from IPython.display import display, clear_output

# %%
# Define data root directory
data_dir = "./"
df = pd.read_csv(os.path.join(data_dir, 'compare.csv'))
df.tail()
# Out:
#                   DATE    GRU_100   실제 값     GRU_1 Closer_to_Real
# 7799  2021-11-30 20:00  73511.180  73662  73186.46        GRU_100
# 7800  2021-11-30 21:00  71288.450  71459  71282.18        GRU_100
# 7801  2021-11-30 22:00  69730.070  69255  69744.35        GRU_100
# 7802  2021-11-30 23:00  68193.860  67679  68227.35        GRU_100
# 7803   2021-12-01 0:00  66969.414  68181  66942.96        GRU_100

# %%
# Extract data
actual = df['실제 값']
closer_to_real = df['Closer_to_Real']
gru_100 = df['GRU_100']
gru_1 = df['GRU_1']
time = pd.to_datetime(df['DATE'])

# %%
# 실제 값과 예측 값을 저장할 리스트 초기화
actual_values = []
predicted_values = []
colors = []
labels = []
times = []

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, clear_output
from matplotlib import pyplot as plt
from matplotlib import animation

# Function to plot the data
def plot_data(actual, gru_data, start_idx):
    plt.plot(actual[start_idx:start_idx + 100], label='Real Data', color='blue')
    plt.xlabel('Index')
    plt.ylabel('Value')
    plt.title(f'Data from index {start_idx} to {start_idx + 99}')
    plt.legend()
    plt.show()

# Loop to update the plot every 10 seconds
for i in range(0, 7804, 100):
    clear_output(wait=True)
    plt.figure(figsize=(10, 5))
    plot_data(actual_values, gru_100, i)
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 21
#      19 plt.figure(figsize=(10, 5))
#      20 plot_data(actual_values, gru_100, i)
# ---> 21 time.sleep(1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'sleep'

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, clear_output
import time

# Function to plot the data
def plot_data(real_data, gru_data, start_idx):
    
    if closer_to_real_value == 'GRU_100':
        gru_100_value = gru_100[i]
        plt.plot(time[max(0, i-window_size+1):i+1], gru_100[max(0, i-window_size+1):i+1], 'ro-', label='GRU_100' if i == 0 else "")
    elif closer_to_real_value == 'GRU_1':
        gru_1_value = gru_1[i]
        plt.plot(time[max(0, i-window_size+1):i+1], gru_1[max(0, i-window_size+1):i+1], 'go-', label='GRU_1' if i == 0 else "")
    
    
    plt.plot(real_data[start_idx:start_idx + 100], label='Real Data', color='blue')
    plt.plot(gru_data[start_idx:start_idx + 100], label='GRU Output', color='red')
    plt.xlabel('Index')
    plt.ylabel('Value')
    plt.legend()
    plt.show()

# Loop to update the plot every 10 seconds
for i in range(0, min(len(actual), len(gru_100)), 100):
    clear_output(wait=True)
    plt.figure(figsize=(10, 5))
    plot_data(actual, gru_100, i)
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[61], line 21
#      19 plt.figure(figsize=(10, 5))
#      20 plot_data(actual, gru_100, i)
# ---> 21 time.sleep(1)
#
# KeyboardInterrupt:

# %%
pip install FuncAnimation
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement FuncAnimation (from versions: none)
# ERROR: No matching distribution found for FuncAnimation

# %%
import random
from itertools import count
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from pandas.core.indexes import interval
 
def animate(i):
    data = pd.read_csv('data4.csv')
    x = data['x_value']
    y1 = data['total_1']
    y2 = data['total_2']
 
    plt.cla()
    plt.plot(x,y1, label='블로그')
    plt.plot(x,y2,label='유튜브')
    
    plt.legend(loc = 'upper left')
    plt.tight_layout()
 
ani = FuncAnimation(plt.gcf(),animate, interval = 1000)
 
plt.tight_layout()
plt.show()
